# %% [markdown]
# <a href="https://colab.research.google.com/github/Bunny825/Final_Project_SE/blob/main/Cardio_Vascular.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import pickle
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense,Dropout

# %%
data=pd.read_csv("/content/cardio_train.csv",sep=";")

# %%
data.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %% [markdown]
# gender:
# 1->women,2->men
# cholesterol:
# 1->normal,2->above normal,3->well abouve normal
# glucose:
# 1->normal,2->above normal,3->well abouve normal
# smoke:
# 1->yes,0->no
# alcohol:
# 1->yes,0->no
# active:
# 1->yes,0->no
# cardio:
# 1->yes,0->no

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB

# %%
data.drop(columns=["id"],axis=1,inplace=True)

# %%
data.head()
# Out:
#      age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0  18393       2     168    62.0    110     80            1     1      0
# 1  20228       1     156    85.0    140     90            3     1      0
# 2  18857       1     165    64.0    130     70            3     1      0
# 3  17623       2     169    82.0    150    100            1     1      0
# 4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
data["cardio"].value_counts()
# Out:
# cardio
# 0    35021
# 1    34979
# Name: count, dtype: int64

# %% [markdown]
# #almost same and balanced dataset

# %%
from sklearn.model_selection import train_test_split
x=data.iloc[:,:-1]
y=data.iloc[:,-1]
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=scaler.fit_transform(x)
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=2,test_size=0.2)
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (56000, 11) (14000, 11) (56000,) (14000,)

# %% [markdown]
# Model building

# %%
pip install -U keras-tuner

# %%
model=Sequential()
model.add(Dense(32,activation="relu",input_dim=11))
model.add(Dense(24,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(8,activation="relu"))
model.add(Dense(1,activation="sigmoid"))

model.compile(optimizer="rmsprop",metrics=["accuracy"],loss="binary_crossentropy")
model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=10)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.6588 - loss: 0.6223 - val_accuracy: 0.7247 - val_loss: 0.5777
# Epoch 2/10
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - accuracy: 0.7289 - loss: 0.5612 - val_accuracy: 0.7289 - val_loss: 0.5680
# Epoch 3/10
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7321 - loss: 0.5489 - val_accuracy: 0.7269 - val_loss: 0.5568
# Epoch 4/10
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7306 - loss: 0.5471 - val_accuracy: 0.7283 - val_loss: 0.5547
# Epoch 5/10
# ...

# %%
input=scaler.transform(np.array([[21862,1,163,69.0,100,70,1,1,0,0,1]]))
model.predict(input)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[0.36672682]], dtype=float32)

# %%
pickle.dump(scaler,open("cardio_scaler.sav","wb"))
model.save("cardio_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
